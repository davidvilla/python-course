# %% [markdown]
# #Introducción al lenguaje Python
#
# El presente curso trata de dar una visión amplia de las características y posibilidades del lenguaje de programación Python, cubriendo tanto el propio lenguaje como las funcionalidades elementales de la librería estándar. Se aborda también el proceso de testing y perfilado de programas.
#
# ##Contenidos
#
# ### Introducción (1)
# * [el intérprete interactivo](intérprete.ipynb)
# * [variables y tipos](variables%20y%20tipos.ipynb)
# * [sentencias de control](sentencias%20de%20control.ipynb)
# * [scripts, shebang y encoding](scripts.ipynb)
#
# ### [Funciones](funciones.ipynb) (1)
# * funciones y paso de parámetros
# * parámetros por defecto y nombrados
# * empaquetado de parámetros
#
# ### [Programación defensiva](defensiva.ipynb) (2)
# * assert
# * testing rudimentario
#
# ### [Errores](errores.ipynb) (2)
# * Tratamiento de excepciones
# * Lanzar excepciones
# * Excepciones de usuario
#
# ### [Módulos](módulos.ipynb) (3)
# * estructura
# * namespaces y pollution
#
# ### [Programación orientada a objetos](POO.ipynb) (2,3)
# * clases, self e \_\_init\_\_
# * \_\_dict\_\_
# * métodos estáticos y de clase
# * herencia
# * información de tipo
# * introspección
#
# ### [Pruebas](testing.ipynb) (3,4)
# * doctests
# * pruebas unitarias
# * FIRST
# * Test suites
# * TDD
# * Dobles de prueba (PENDIENTE)
#
# ### Programación orientada a objetos II
# * [métodos especiales y sobrecarga de operadores](operator-overload.ipynb) (5)
# * [functors](functors.ipynb) (7)
# * [propiedades](properties.ipynb) (7)
# * principios SOLID (PENDIENTE)
#
# ### [Programación funcional](funcional.ipynb) (4)
# * funciones lambda
# * map, filter y reduce
# * comprensión de listas, conjuntos y diccionarios
# * decoradores (funciones de orden superior)
# * funciones parcialmente especificadas (6)
# * [closures](ámbito.ipynb) (5)
#
# ### [Iterables](iteradores.ipynb)
# * Crear un tipo iterable (5)
# * generadores (7)
# * itertools (7)
#
# ### Matemáticas
# * [numpy](numpy.ipynb) (5,6)
# * [matplotlib](matplotlib.ipynb) (7)
# * pandas
#
# ### [Entrada/Salida](EntradaSalida.ipynb) (7)
# * E/S estándar
# * Ficheros
# * [Sockets](sockets.ipynb) (8)
#
# ### [Servicios del sistema operativo](os.ipynb) (8)
# * línea de comandos
# * sistema de ficheros
# * señales
# * procesos y subprocesos
# * usuarios
#
# ### [Bindings C/C++](bindings.ipynb) (8)
# * Empotrar Python
#   * Con libpython
#   * Con boost
# * Extender Python
#   * Con libpython
#   * Con ctypes
#   * Con boost
#
# ### Codificación de datos (PENDIENTE)
# * unicode y sistemas de codificación
# * representación de datos
# * struct
# * pickle
#
# ### Temas avanzados
# * descriptores
# * decoradores de clases
# * metaprogramación
#
# ### Más
# * expresiones regulares
# * requests
# * patrones de diseño
# * notebook
# * signals / eventos
# * bindings a C/C++
# * multiprocessing
# * concurrencia
